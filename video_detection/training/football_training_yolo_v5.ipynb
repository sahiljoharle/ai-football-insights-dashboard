# %% [markdown]
# # Lets Get the Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AwugkqjN5fPANhfXhTXG")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# /Users/sahiljoharle/Downloads/StepOut Mini/ai-football-insights-dashboard/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 2533.99it/s]

# %%
dataset.location
# Out:
# '/Users/sahiljoharle/Downloads/StepOut Mini/ai-football-insights-dashboard/video_detection/training /football-players-detection-1'

# %% [markdown]
# # Training

# %%
# !yolo task = detect mode = train model = yolov5x.pt data = {dataset.location}/data.yaml epochs = 100 imgsz = 640

# %% [markdown]
# ### I will Train in Google Colab As my Pc can't handel It

# %%
"""

100 epochs completed in 2.390 hours.
Optimizer stripped from /content/runs/detect/train/weights/last.pt, 195.0MB
Optimizer stripped from /content/runs/detect/train/weights/best.pt, 195.0MB

Validating /content/runs/detect/train/weights/best.pt...
Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
YOLOv5x summary (fused): 151 layers, 97,156,460 parameters, 0 gradients, 246.0 GFLOPs
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s
                   all         38        905      0.882      0.829      0.845      0.585
                  ball         35         35      0.777      0.486      0.465      0.197
            goalkeeper         27         27      0.891      0.909      0.977      0.735
                player         38        754      0.967      0.983      0.985      0.764
               referee         38         89      0.893       0.94      0.952      0.643
Speed: 0.1ms preprocess, 17.8ms inference, 0.0ms loss, 2.5ms postprocess per image
Results saved to /content/runs/detect/train 

"""
# Out:
# '\n\n100 epochs completed in 2.390 hours.\nOptimizer stripped from /content/runs/detect/train/weights/last.pt, 195.0MB\nOptimizer stripped from /content/runs/detect/train/weights/best.pt, 195.0MB\n\nValidating /content/runs/detect/train/weights/best.pt...\nUltralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)\nYOLOv5x summary (fused): 151 layers, 97,156,460 parameters, 0 gradients, 246.0 GFLOPs\n                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 1.7it/s 1.2s\n                   all         38        905      0.882      0.829      0.845      0.585\n                  ball         35         35      0.777      0.486      0.465      0.197\n            goalkeeper         27         27      0.891      0.909      0.977      0.735\n                player         38        754      0.967      0.983      0.985      0.764\n               referee         38         89      0.893       0.94      0.952      0
# ...
